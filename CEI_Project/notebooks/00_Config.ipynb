# %% [markdown]
# # Customer Support Ticket Resolution Pipeline
#
# **Pipeline Design:** Medallion Architecture (Bronze → Silver → Gold)
#
# ## Configuration
#
# This notebook initializes the project environment for the Customer Support Ticket Resolution Pipeline.
#
# ### Objectives
# - Import required libraries
# - Configure the project workspace
# - Create the project schema
# - Define table references
# - Verify the project configuration

# %%
# Import Required Libraries

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from delta.tables import DeltaTable

import re

# %% [markdown]
# ## Configure Project
#
# Create widgets to define the catalog and schema. Using widgets makes the notebook reusable across different environments without changing the code.

# %%
# Remove existing widgets (if any)
dbutils.widgets.removeAll()

# Create project widgets
dbutils.widgets.text("catalog", "workspace")
dbutils.widgets.text("schema", "hrm6131_landing")

# Read widget values
CATALOG = dbutils.widgets.get("catalog")
SCHEMA = dbutils.widgets.get("schema")

# %% [markdown]
# ## Create Project Schema

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA}")
# Out:
# DataFrame[]

# %% [markdown]
# ## Define Table References
#
# Create fully qualified table names that will be used throughout the pipeline.

# %%
# Raw Tables
TBL_PROFILES = f"{CATALOG}.{SCHEMA}.agent_profiles"
TBL_DAY1 = f"{CATALOG}.{SCHEMA}.day1_tickets"
TBL_DAY2 = f"{CATALOG}.{SCHEMA}.day2_tickets"

# Bronze Tables
BRONZE_DAY1 = f"{CATALOG}.{SCHEMA}.bronze_day1"
BRONZE_DAY2 = f"{CATALOG}.{SCHEMA}.bronze_day2"
BRONZE_PROFILES = f"{CATALOG}.{SCHEMA}.bronze_profiles"

# Silver Tables
SILVER_TICKETS = f"{CATALOG}.{SCHEMA}.silver_tickets"

# Gold Tables
GOLD_TEAM_PERFORMANCE = f"{CATALOG}.{SCHEMA}.gold_team_performance"
GOLD_AGENT_PERFORMANCE = f"{CATALOG}.{SCHEMA}.gold_agent_performance"
GOLD_QUALITY_COMPLIANCE = f"{CATALOG}.{SCHEMA}.gold_quality_compliance"
GOLD_DAY2_CARRYOVER = f"{CATALOG}.{SCHEMA}.gold_day2_carryover"

# %% [markdown]
# ## Verify Configuration

# %%
print("Project configuration loaded successfully.")
print(f"Catalog : {CATALOG}")
print(f"Schema  : {SCHEMA}")
# Out:
# Project configuration loaded successfully.
# Catalog : workspace
# Schema  : hrm6131_landing

# %%
# Project Name

PROJECT_NAME = "Customer Support Ticket Resolution Pipeline"
